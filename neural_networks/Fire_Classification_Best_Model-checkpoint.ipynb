# %% [markdown]
# ## Dataset Source
# https://www.kaggle.com/phylake1337/fire-dataset/notebooks

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow import keras
from sklearn.metrics import roc_curve, auc, confusion_matrix
from matplotlib import pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import os
import random
import seaborn as sns
from tqdm import tqdm
from PIL import Image 
import cv2
sns.set_theme()

# %%
DATADIR = './fire_dataset'
IMG_SIZE = (299,299)
NUM_CLASSES = len(os.listdir(DATADIR))

#Split data into train, test, and validation
def split_data(training_data):
    train_data = []
    validation_data = []
    test_data = []
    for i in range(NUM_CLASSES):
        i_data = []
        for features,label in training_data:
            if label == i:
                i_data.append([features,label])
        random.shuffle(i_data)
        num_samples = len(i_data)
        test_split = round(num_samples*0.6)
        validation_split = round(num_samples*.15)
        train_data+= i_data[0:test_split]
        validation_data += i_data[test_split:test_split+validation_split]
        test_data+=i_data[test_split+validation_split:len(i_data)]
        print(len(i_data))
    return train_data,test_data, validation_data

#Create training data using R/G color ratio
def create_training_data_CR():
    training_data = []
    for i,category in enumerate(os.listdir(DATADIR)):
        label = i
        print("adding", category)
        for i, path in enumerate(os.listdir(os.path.join(DATADIR,category))):
            if i < 489: #To keep dataset balanced, same number of fire & non-fire images
                img = Image.open(os.path.join(DATADIR,category,path))
                img = img.resize(IMG_SIZE)
                I = np.asarray(img)
                if I.shape == (299,299,3): #keeping only color images
                    I_intensity = (I[:,:,1] > 100) # identify pixels with low GREEN values - they are less reliable
                    I_cr = I[:,:,0]/I[:,:,1] # This is the ratio of Red (0) to Green (1)
                    I_cr[~I_intensity] = 1.0 # small green values would have infinite or near infinite ratios, replace with a "big" number instead
                    I_sig = (I[:,:,0] > 1.2*I[:,:,1]) & I_intensity
                    training_data.append([I_sig,label])
    return training_data

#Reshape and normalize features
def reshape_data_CR(data, shape):
    X = []
    Y = []
    for features, label in data:
        X.append(features.reshape(shape))
        Y.append(tf.keras.utils.to_categorical(label, num_classes=2, dtype="float32"))
    scaler = MinMaxScaler(feature_range=(0, 1))
    rescaled_features = scaler.fit_transform(X)
    Y = np.asarray(Y)
    return rescaled_features,Y

# %%
fig, ax = plt.subplots(ncols = 2)
category = os.listdir(DATADIR)[0]
path = os.listdir(os.path.join(DATADIR,category))[45]
img = Image.open(os.path.join(DATADIR,category,path))

img = img.resize(IMG_SIZE)
I = np.asarray(img)
print(I.shape)
I_intensity = (I[:,:,1] > 100)
I_cr = I[:,:,0]/I[:,:,1] 
I_cr[~I_intensity] = 1.0
I_sig = (I[:,:,0] > 1.3*I[:,:,1]) & I_intensity
ax[0].imshow(img)
ax[1].imshow(I_sig)
# Out:
# (299, 299, 3)
# C:\Users\kaitl\anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\kaitl\anaconda3\lib\site-packages\ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in true_divide
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Create training data for color ratio simple model
training_data_CR = create_training_data_CR()
INPUT_SHAPE = (299*299,)

train_data, test_data, validation_data = split_data(training_data_CR)
x_train, y_train = reshape_data_CR(train_data, INPUT_SHAPE)
x_test, y_test = reshape_data_CR(test_data, INPUT_SHAPE)
x_val, y_val = reshape_data_CR(validation_data, INPUT_SHAPE)
print("Train:", x_train.shape, "Test:", x_test.shape, "Validation:", x_val.shape)
# Out:
# adding fire_images
# C:\Users\kaitl\anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: divide by zero encountered in true_divide
# C:\Users\kaitl\anaconda3\lib\site-packages\ipykernel_launcher.py:60: RuntimeWarning: invalid value encountered in true_divide
# adding non_fire_images
# 486
# 478
# Train: (579, 89401) Test: (240, 89401) Validation: (145, 89401)

# %%
model = Sequential() # declare model
model.add(Dense(NUM_CLASSES, input_shape=INPUT_SHAPE, kernel_initializer='he_normal')) # firstlayer
model.add(Activation('tanh'))
model.add(Dense(512, activation='tanh'))
model.add(Dense(NUM_CLASSES, kernel_initializer='he_normal')) # last layer
model.add(Activation('softmax'))
opt = SGD(lr=0.001)

model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
callbacks = [EarlyStopping(monitor = 'val_loss',patience = 10,restore_best_weights=True)]

#Train model
history = model.fit(x_train,y_train,validation_data=(x_val, y_val),epochs = 100,batch_size = 32,callbacks = callbacks)

# Report Results
# print(history.history)
y_pred = model.predict(x_test)
score = model.evaluate(x_test, y_test, verbose=2)
print(f'Test loss: {score[0]} / Test accuracy: {score[1]}')
# Out:
# Epoch 1/100
# 19/19 [==============================] - 0s 15ms/step - loss: 0.6926 - accuracy: 0.4180 - val_loss: 0.6738 - val_accuracy: 0.5448
# Epoch 2/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6734 - accuracy: 0.6062 - val_loss: 0.6662 - val_accuracy: 0.5931
# Epoch 3/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.6667 - accuracy: 0.6062 - val_loss: 0.6609 - val_accuracy: 0.7310
# Epoch 4/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6614 - accuracy: 0.7306 - val_loss: 0.6563 - val_accuracy: 0.7793
# Epoch 5/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6565 - accuracy: 0.7582 - val_loss: 0.6517 - val_accuracy: 0.7931
# Epoch 6/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6516 - accuracy: 0.7858 - val_loss: 0.6465 - val_accuracy: 0.8000
# Epoch 7/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6462 - accuracy: 0.7927 - val_loss: 0.6414 - val_accuracy: 0.7931
# Epoch 8/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6407 - accuracy: 0.7997 - val_loss: 0.6367 - val_accuracy: 0.7931
# Epoch 9/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6354 - accuracy: 0.8031 - val_loss: 0.6320 - val_accuracy: 0.8138
# Epoch 10/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6301 - accuracy: 0.8135 - val_loss: 0.6277 - val_accuracy: 0.8207
# Epoch 11/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.6249 - accuracy: 0.8221 - val_loss: 0.6230 - val_accuracy: 0.8276
# Epoch 12/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6191 - accuracy: 0.8273 - val_loss: 0.6190 - val_accuracy: 0.8207
# Epoch 13/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6132 - accuracy: 0.8446 - val_loss: 0.6144 - val_accuracy: 0.8276
# Epoch 14/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6070 - accuracy: 0.8497 - val_loss: 0.6102 - val_accuracy: 0.8276
# Epoch 15/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.6005 - accuracy: 0.8601 - val_loss: 0.6057 - val_accuracy: 0.8345
# Epoch 16/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5937 - accuracy: 0.8653 - val_loss: 0.6014 - val_accuracy: 0.8483
# Epoch 17/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5869 - accuracy: 0.8774 - val_loss: 0.5976 - val_accuracy: 0.8690
# Epoch 18/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5802 - accuracy: 0.8860 - val_loss: 0.5937 - val_accuracy: 0.8690
# Epoch 19/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5732 - accuracy: 0.8998 - val_loss: 0.5896 - val_accuracy: 0.8759
# Epoch 20/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5657 - accuracy: 0.9136 - val_loss: 0.5866 - val_accuracy: 0.8759
# Epoch 21/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5581 - accuracy: 0.9171 - val_loss: 0.5826 - val_accuracy: 0.8690
# Epoch 22/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5502 - accuracy: 0.9206 - val_loss: 0.5779 - val_accuracy: 0.8759
# Epoch 23/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5423 - accuracy: 0.9240 - val_loss: 0.5733 - val_accuracy: 0.8759
# Epoch 24/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5343 - accuracy: 0.9240 - val_loss: 0.5689 - val_accuracy: 0.8759
# Epoch 25/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5260 - accuracy: 0.9309 - val_loss: 0.5645 - val_accuracy: 0.8759
# Epoch 26/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5178 - accuracy: 0.9361 - val_loss: 0.5615 - val_accuracy: 0.8690
# Epoch 27/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5093 - accuracy: 0.9430 - val_loss: 0.5567 - val_accuracy: 0.8690
# Epoch 28/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.5009 - accuracy: 0.9499 - val_loss: 0.5519 - val_accuracy: 0.8828
# Epoch 29/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4928 - accuracy: 0.9499 - val_loss: 0.5470 - val_accuracy: 0.8828
# Epoch 30/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4847 - accuracy: 0.9534 - val_loss: 0.5430 - val_accuracy: 0.8897
# Epoch 31/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4769 - accuracy: 0.9568 - val_loss: 0.5388 - val_accuracy: 0.8897
# Epoch 32/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4691 - accuracy: 0.9585 - val_loss: 0.5346 - val_accuracy: 0.8897
# Epoch 33/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4614 - accuracy: 0.9603 - val_loss: 0.5306 - val_accuracy: 0.8897
# Epoch 34/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4539 - accuracy: 0.9603 - val_loss: 0.5267 - val_accuracy: 0.8897
# Epoch 35/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4462 - accuracy: 0.9603 - val_loss: 0.5224 - val_accuracy: 0.8897
# Epoch 36/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4387 - accuracy: 0.9603 - val_loss: 0.5179 - val_accuracy: 0.8966
# Epoch 37/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4311 - accuracy: 0.9620 - val_loss: 0.5146 - val_accuracy: 0.9034
# Epoch 38/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4239 - accuracy: 0.9620 - val_loss: 0.5107 - val_accuracy: 0.8966
# Epoch 39/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4166 - accuracy: 0.9620 - val_loss: 0.5068 - val_accuracy: 0.8966
# Epoch 40/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4095 - accuracy: 0.9620 - val_loss: 0.5035 - val_accuracy: 0.9034
# Epoch 41/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.4023 - accuracy: 0.9620 - val_loss: 0.5010 - val_accuracy: 0.8966
# Epoch 42/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3951 - accuracy: 0.9620 - val_loss: 0.4966 - val_accuracy: 0.9034
# Epoch 43/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3884 - accuracy: 0.9637 - val_loss: 0.4923 - val_accuracy: 0.9103
# Epoch 44/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3816 - accuracy: 0.9637 - val_loss: 0.4885 - val_accuracy: 0.9103
# Epoch 45/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3751 - accuracy: 0.9655 - val_loss: 0.4851 - val_accuracy: 0.9034
# Epoch 46/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3688 - accuracy: 0.9655 - val_loss: 0.4815 - val_accuracy: 0.9034
# Epoch 47/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3625 - accuracy: 0.9672 - val_loss: 0.4782 - val_accuracy: 0.9034
# Epoch 48/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3563 - accuracy: 0.9689 - val_loss: 0.4752 - val_accuracy: 0.9034
# Epoch 49/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3503 - accuracy: 0.9706 - val_loss: 0.4725 - val_accuracy: 0.9034
# Epoch 50/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3447 - accuracy: 0.9741 - val_loss: 0.4693 - val_accuracy: 0.9034
# Epoch 51/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3388 - accuracy: 0.9758 - val_loss: 0.4654 - val_accuracy: 0.9034
# Epoch 52/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3332 - accuracy: 0.9775 - val_loss: 0.4616 - val_accuracy: 0.9034
# Epoch 53/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3277 - accuracy: 0.9775 - val_loss: 0.4572 - val_accuracy: 0.9034
# Epoch 54/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3225 - accuracy: 0.9775 - val_loss: 0.4547 - val_accuracy: 0.9034
# Epoch 55/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3171 - accuracy: 0.9775 - val_loss: 0.4519 - val_accuracy: 0.9034
# Epoch 56/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3121 - accuracy: 0.9775 - val_loss: 0.4490 - val_accuracy: 0.9034
# Epoch 57/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3071 - accuracy: 0.9793 - val_loss: 0.4464 - val_accuracy: 0.9034
# Epoch 58/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3023 - accuracy: 0.9810 - val_loss: 0.4437 - val_accuracy: 0.9034
# Epoch 59/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2974 - accuracy: 0.9810 - val_loss: 0.4413 - val_accuracy: 0.9034
# Epoch 60/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2927 - accuracy: 0.9810 - val_loss: 0.4386 - val_accuracy: 0.9034
# Epoch 61/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2882 - accuracy: 0.9810 - val_loss: 0.4359 - val_accuracy: 0.9034
# Epoch 62/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2838 - accuracy: 0.9810 - val_loss: 0.4325 - val_accuracy: 0.9034
# Epoch 63/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2795 - accuracy: 0.9810 - val_loss: 0.4298 - val_accuracy: 0.9034
# Epoch 64/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2753 - accuracy: 0.9810 - val_loss: 0.4270 - val_accuracy: 0.9034
# Epoch 65/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2712 - accuracy: 0.9810 - val_loss: 0.4246 - val_accuracy: 0.9034
# Epoch 66/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2673 - accuracy: 0.9810 - val_loss: 0.4224 - val_accuracy: 0.9034
# Epoch 67/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2635 - accuracy: 0.9810 - val_loss: 0.4203 - val_accuracy: 0.9034
# Epoch 68/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2597 - accuracy: 0.9810 - val_loss: 0.4180 - val_accuracy: 0.9034
# Epoch 69/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2563 - accuracy: 0.9810 - val_loss: 0.4157 - val_accuracy: 0.9034
# Epoch 70/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2528 - accuracy: 0.9810 - val_loss: 0.4135 - val_accuracy: 0.9034
# Epoch 71/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2493 - accuracy: 0.9810 - val_loss: 0.4114 - val_accuracy: 0.9034
# Epoch 72/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2459 - accuracy: 0.9810 - val_loss: 0.4093 - val_accuracy: 0.9034
# Epoch 73/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2426 - accuracy: 0.9810 - val_loss: 0.4072 - val_accuracy: 0.9034
# Epoch 74/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2394 - accuracy: 0.9810 - val_loss: 0.4052 - val_accuracy: 0.9034
# Epoch 75/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2363 - accuracy: 0.9810 - val_loss: 0.4031 - val_accuracy: 0.9034
# Epoch 76/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2333 - accuracy: 0.9810 - val_loss: 0.4019 - val_accuracy: 0.8966
# Epoch 77/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2304 - accuracy: 0.9810 - val_loss: 0.3993 - val_accuracy: 0.8966
# Epoch 78/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2274 - accuracy: 0.9810 - val_loss: 0.3974 - val_accuracy: 0.8966
# Epoch 79/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2246 - accuracy: 0.9810 - val_loss: 0.3955 - val_accuracy: 0.8966
# Epoch 80/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.2219 - accuracy: 0.9810 - val_loss: 0.3935 - val_accuracy: 0.8966
# Epoch 81/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2192 - accuracy: 0.9810 - val_loss: 0.3919 - val_accuracy: 0.8966
# Epoch 82/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2166 - accuracy: 0.9810 - val_loss: 0.3902 - val_accuracy: 0.8966
# Epoch 83/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2140 - accuracy: 0.9810 - val_loss: 0.3882 - val_accuracy: 0.8966
# Epoch 84/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2114 - accuracy: 0.9810 - val_loss: 0.3866 - val_accuracy: 0.8966
# Epoch 85/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2090 - accuracy: 0.9810 - val_loss: 0.3850 - val_accuracy: 0.8966
# Epoch 86/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2065 - accuracy: 0.9810 - val_loss: 0.3846 - val_accuracy: 0.8966
# Epoch 87/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2042 - accuracy: 0.9810 - val_loss: 0.3834 - val_accuracy: 0.8966
# Epoch 88/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.2020 - accuracy: 0.9810 - val_loss: 0.3818 - val_accuracy: 0.8966
# Epoch 89/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1998 - accuracy: 0.9810 - val_loss: 0.3806 - val_accuracy: 0.8966
# Epoch 90/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1976 - accuracy: 0.9810 - val_loss: 0.3795 - val_accuracy: 0.8966
# Epoch 91/100
# 19/19 [==============================] - 0s 9ms/step - loss: 0.1955 - accuracy: 0.9810 - val_loss: 0.3785 - val_accuracy: 0.8966
# Epoch 92/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1935 - accuracy: 0.9810 - val_loss: 0.3773 - val_accuracy: 0.8966
# Epoch 93/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1915 - accuracy: 0.9810 - val_loss: 0.3758 - val_accuracy: 0.8966
# Epoch 94/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1895 - accuracy: 0.9810 - val_loss: 0.3743 - val_accuracy: 0.8966
# Epoch 95/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1876 - accuracy: 0.9810 - val_loss: 0.3733 - val_accuracy: 0.8966
# Epoch 96/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1857 - accuracy: 0.9810 - val_loss: 0.3720 - val_accuracy: 0.8966
# Epoch 97/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1839 - accuracy: 0.9810 - val_loss: 0.3710 - val_accuracy: 0.8966
# Epoch 98/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1821 - accuracy: 0.9810 - val_loss: 0.3694 - val_accuracy: 0.8966
# Epoch 99/100
# 19/19 [==============================] - 0s 8ms/step - loss: 0.1803 - accuracy: 0.9810 - val_loss: 0.3679 - val_accuracy: 0.8966
# Epoch 100/100
# 19/19 [==============================] - 0s 7ms/step - loss: 0.1786 - accuracy: 0.9810 - val_loss: 0.3669 - val_accuracy: 0.8966
# 8/8 - 0s - loss: 0.2504 - accuracy: 0.9667
# Test loss: 0.25044676661491394 / Test accuracy: 0.9666666388511658

# %%
#Plot Epoch vs. Model Accuracy 
plt.clf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Create labels for confusion matrix
labels = ["Fire", "No Fire"]
# for label in os.listdir(DATADIR):
#     labels.append(label)
    
#Get data for confusion matrix
pred = np.argmax(y_pred, axis=-1)
test = np.argmax(y_test, axis=-1)
# print(y_pred)
# print(y_test)
confusion_data = confusion_matrix(test, pred)

#plot incorrectly classified images
heat_map = sns.heatmap(confusion_data, cmap='Blues',annot=True, linewidths=0, fmt='g', xticklabels=labels, yticklabels=labels)
plt.xlabel("Predicted Values")
plt.ylabel("True Values")
plt.title("Confusion Matrix")
plt.show()
